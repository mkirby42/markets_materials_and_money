# %%
from IPython.display import Image

# %%
Image("Screenshot 2024-11-03 at 7.31.49 PM.png", width=400)

# %% [markdown]
# Can we get a finer resolution of energy prices... over time?
# What about a map of transport prices. sea, road, rail
# Coal, oil, iron ore
